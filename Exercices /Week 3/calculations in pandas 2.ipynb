# %%
import numpy as np
import pandas as pd

car = pd.read_excel(r'C:\Users\HP\Downloads\vehicles.xlsx')

# %%
car.head(5)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
car['Transmission'].value_counts()
# Out:
# Automatic 4-spd                     10585
# Manual 5-spd                         7787
# Automatic (S6)                       2631
# Automatic 3-spd                      2597
# Manual 6-spd                         2423
# Automatic 5-spd                      2171
# Automatic 6-spd                      1432
# Manual 4-spd                         1306
# Automatic (S8)                        960
# Automatic (S5)                        822
# Automatic (variable gear ratios)      675
# Automatic 7-spd                       662
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        229
# Auto(AM7)                             157
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# Manual 3-spd                           74
# ...

# %%
car.loc[car['Transmission'].str.startswith('A')]
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35946             smart         fortwo coupe  2012                  1.0
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
car.loc[car['Transmission'].str.startswith('A'), 'TransType'] = 'Automatic'
car.loc[car['Transmission'].str.startswith('M'), 'TransType'] = 'Manual'

# %%
car
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
avg_mpg = car.groupby('Make').agg({'Combined MPG':'mean'})
avg_mpg
# Out:
#                              Combined MPG
# Make
# AM General                      14.750000
# ASC Incorporated                16.000000
# Acura                           21.506623
# Alfa Romeo                      19.512195
# American Motors Corporation     17.681818
# ...                                   ...
# Volkswagen                      24.093601
# Volvo                           20.605300
# Wallace Environmental           13.875000
# Yugo                            25.000000
# smart                           35.800000
#
# [127 rows x 1 columns]

# %%
avg_cyl = car.groupby('Year', as_index=False).agg({'Cylinders':'mean'})
avg_cyl
# Out:
#     Year  Cylinders
# 0   1984   6.102326
# 1   1985   5.388362
# 2   1986   5.430976
# 3   1987   5.384808
# 4   1988   5.469169
# 5   1989   5.476486
# 6   1990   5.498127
# 7   1991   5.603387
# 8   1992   5.628726
# 9   1993   5.595172
# 10  1994   5.712513
# 11  1995   5.868534
# 12  1996   5.624511
# 13  1997   5.671523
# 14  1998   5.668774
# 15  1999   5.713768
# 16  2000   5.740024
# 17  2001   5.756098
# 18  2002   5.839750
# 19  2003   5.961315
# 20  2004   5.955076
# 21  2005   5.945502
# 22  2006   6.102821
# 23  2007   6.166075
# 24  2008   6.196791
# 25  2009   6.122570
# 26  2010   5.963899
# 27  2011   5.998221
# 28  2012   5.948200
# 29  2013   5.831336
# 30  2014   5.815029
# 31  2015   5.715190
# 32  2016   5.609935
# 33  2017   5.696616

# %%
avg_mpg = car.groupby('Make', as_index=False).agg({'Combined MPG':'mean'})

# %%
avg_mpg
# Out:
#                             Make  Combined MPG
# 0                     AM General     14.750000
# 1               ASC Incorporated     16.000000
# 2                          Acura     21.506623
# 3                     Alfa Romeo     19.512195
# 4    American Motors Corporation     17.681818
# ..                           ...           ...
# 122                   Volkswagen     24.093601
# 123                        Volvo     20.605300
# 124        Wallace Environmental     13.875000
# 125                         Yugo     25.000000
# 126                        smart     35.800000
#
# [127 rows x 2 columns]

# %%
sum_mpg.columns = ['Make', 'Sum_MPG']

# %%
avg_mpg
# Out:
#                             Make    Avg_MPG
# 0                     AM General  14.750000
# 1               ASC Incorporated  16.000000
# 2                          Acura  21.506623
# 3                     Alfa Romeo  19.512195
# 4    American Motors Corporation  17.681818
# ..                           ...        ...
# 122                   Volkswagen  24.093601
# 123                        Volvo  20.605300
# 124        Wallace Environmental  13.875000
# 125                         Yugo  25.000000
# 126                        smart  35.800000
#
# [127 rows x 2 columns]

# %%
data1 = pd.merge(car, avg_mpg, on='Make')
data1.head(10)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
# 5             Acura          2.2CL/3.0CL  1997                  2.2
# 6             Acura          2.2CL/3.0CL  1997                  2.2
# 7             Acura          2.2CL/3.0CL  1997                  3.0
# 8             Acura          2.3CL/3.0CL  1998                  2.3
# 9             Acura          2.3CL/3.0CL  1998                  2.3
#
#    Cylinders     Transmission         Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# ...

# %%
filtered = car[(car['Make']=='Ford') & 
                (car['TransType']== "Automatic") ]
filtered
# Out:
#        Make               Model  Year  Engine Displacement  Cylinders  \
# 11440  Ford        Aerostar Van  1986                  2.3          4
# 11442  Ford        Aerostar Van  1986                  2.8          6
# 11445  Ford        Aerostar Van  1986                  3.0          6
# 11446  Ford        Aerostar Van  1987                  2.3          4
# 11448  Ford        Aerostar Van  1987                  3.0          6
# ...     ...                 ...   ...                  ...        ...
# 14381  Ford  Windstar FWD Wagon  2000                  3.0          6
# 14382  Ford  Windstar FWD Wagon  2000                  3.8          6
# 14383  Ford  Windstar FWD Wagon  2001                  3.8          6
# 14384  Ford  Windstar FWD Wagon  2002                  3.8          6
# 14385  Ford  Windstar FWD Wagon  2003                  3.8          6
#
#           Transmission         Drivetrain  Vehicle Class Fuel Type  \
# ...

# %%
mpg_labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
mpg_labels
# Out:
# ['Very Low', 'Low', 'Moderate', 'High', 'Very High']

# %%
car["bins1"] = pd.cut(car['Combined MPG'],5, labels=mpg_labels)

# %%
car
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...
