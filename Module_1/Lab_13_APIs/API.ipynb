# %%
import json    #responsible of json (format)
import requests   #responsible for getting that information

response = requests.get('https://jsonplaceholder.typicode.com/todos')
print(response.status_code)
results = response.json()
# Out:
# 200

# %%
import pandas as pd      #responsible for gettting the json ant covert into a table (dataframe)
data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
response = requests.get('https://api.thedogapi.com/v1/images/search?limit=5')

# %%
response.text
# Out:
# '[{"id":"20ILpw3eY","url":"https://cdn2.thedogapi.com/images/20ILpw3eY.jpg","width":1546,"height":1213},{"id":"LmGFTdAev","url":"https://cdn2.thedogapi.com/images/LmGFTdAev.jpg","width":500,"height":416},{"id":"jQ87YWkhV","url":"https://cdn2.thedogapi.com/images/jQ87YWkhV.jpg","width":4578,"height":3434},{"id":"DSgAKoZve","url":"https://cdn2.thedogapi.com/images/DSgAKoZve.jpg","width":220,"height":330},{"id":"Y7LMrWoZv","url":"https://cdn2.thedogapi.com/images/Y7LMrWoZv.jpg","width":940,"height":626}]'

# %%
response = requests.get('https://api.thedogapi.com/v1/breeds')
results = response.json()
data = pd.DataFrame(results)
data.shape
data.head(10)
# Out:
#                                           weight  \
# 0      {'imperial': '6 - 13', 'metric': '3 - 6'}
# 1   {'imperial': '50 - 60', 'metric': '23 - 27'}
# 2   {'imperial': '44 - 66', 'metric': '20 - 30'}
# 3   {'imperial': '40 - 65', 'metric': '18 - 29'}
# 4  {'imperial': '90 - 120', 'metric': '41 - 54'}
# 5  {'imperial': '65 - 115', 'metric': '29 - 52'}
# 6   {'imperial': '55 - 90', 'metric': '25 - 41'}
# 7   {'imperial': '38 - 50', 'metric': '17 - 23'}
# 8  {'imperial': '65 - 100', 'metric': '29 - 45'}
# 9  {'imperial': '60 - 120', 'metric': '27 - 54'}
#
#                                           height  id  \
# 0  {'imperial': '9 - 11.5', 'metric': '23 - 29'}   1
# 1   {'imperial': '25 - 27', 'metric': '64 - 69'}   2
# 2             {'imperial': '30', 'metric': '76'}   3
# 3   {'imperial': '21 - 23', 'metric': '53 - 58'}   4
# 4   {'imperial': '28 - 34', 'metric': '71 - 86'}   5
# 5   {'imperial': '24 - 28', 'metric': '61 - 71'}   6
# ...

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(10)
# Out:
#             id              type  \
# 0  24642388259         PushEvent
# 1  24642388226         PushEvent
# 2  24642388271       PublicEvent
# 3  24642388288       CreateEvent
# 4  24642388225         PushEvent
# 5  24642388256         PushEvent
# 6  24642388195         PushEvent
# 7  24642388227         PushEvent
# 8  24642388242         PushEvent
# 9  24642388270  PullRequestEvent
#
#                                                actor  \
# 0  {'id': 41898282, 'login': 'github-actions[bot]...
# 1  {'id': 103371767, 'login': 'paoloevan', 'displ...
# 2  {'id': 47596558, 'login': 'pincr24', 'display_...
# 3  {'id': 114974902, 'login': 'apsarasinthudecha'...
# 4  {'id': 67372333, 'login': 'readloud', 'display...
# 5  {'id': 6104, 'login': 'jasonlong', 'display_lo...
# 6  {'id': 69583657, 'login': 'OTube', 'display_lo...
# 7  {'id': 41898282, 'login': 'github-actions[bot]...
# 8  {'id': 41898282, 'login': 'github-actions[bot]...
# 9  {'id': 36852, 'login': 'daonb', 'display_login...
#
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)


flat.head(10)
# Out:
#             id              type  public            created_at   actor_id  \
# 0  24642388259         PushEvent    True  2022-10-17T12:39:22Z   41898282
# 1  24642388226         PushEvent    True  2022-10-17T12:39:22Z  103371767
# 2  24642388271       PublicEvent    True  2022-10-17T12:39:22Z   47596558
# 3  24642388288       CreateEvent    True  2022-10-17T12:39:22Z  114974902
# 4  24642388225         PushEvent    True  2022-10-17T12:39:22Z   67372333
# 5  24642388256         PushEvent    True  2022-10-17T12:39:22Z       6104
# 6  24642388195         PushEvent    True  2022-10-17T12:39:22Z   69583657
# 7  24642388227         PushEvent    True  2022-10-17T12:39:22Z   41898282
# 8  24642388242         PushEvent    True  2022-10-17T12:39:22Z   41898282
# 9  24642388270  PullRequestEvent    True  2022-10-17T12:39:22Z      36852
#
#            actor_login actor_display_login actor_gravatar_id  \
# 0  github-actions[bot]      github-actions
# 1            paoloevan           paoloevan
# ...

# %%
results = response.json()
flattened_data = pd.json_normalize(results)

flattened_data
# Out:
#              id               type  public            created_at   actor.id  \
# 0   24642388259          PushEvent    True  2022-10-17T12:39:22Z   41898282
# 1   24642388226          PushEvent    True  2022-10-17T12:39:22Z  103371767
# 2   24642388271        PublicEvent    True  2022-10-17T12:39:22Z   47596558
# 3   24642388288        CreateEvent    True  2022-10-17T12:39:22Z  114974902
# 4   24642388225          PushEvent    True  2022-10-17T12:39:22Z   67372333
# 5   24642388256          PushEvent    True  2022-10-17T12:39:22Z       6104
# 6   24642388195          PushEvent    True  2022-10-17T12:39:22Z   69583657
# 7   24642388227          PushEvent    True  2022-10-17T12:39:22Z   41898282
# 8   24642388242          PushEvent    True  2022-10-17T12:39:22Z   41898282
# 9   24642388270   PullRequestEvent    True  2022-10-17T12:39:22Z      36852
# 10  24642388232          PushEvent    True  2022-10-17T12:39:22Z   67886455
# ...

# %%
flattened_data["type"].value_counts()
# Out:
# PushEvent            16
# CreateEvent           5
# PullRequestEvent      4
# DeleteEvent           2
# PublicEvent           1
# WatchEvent            1
# IssueCommentEvent     1
# Name: type, dtype: int64

# %%
response = requests.get('https://api.github.com/events')

results = response.json()

# %%
# Out:
#   Input In [36]
#     curl -u JaimeSastreCrespo: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 https://github.com/JaimeSastreCrespo
#             ^
# SyntaxError: invalid syntax
