# %%
#first install library

! pip install wbgapi

# %%
import pandas as pd
import matplotlib.pyplot as plt    #for visualization
import wbgapi as wb

# %%
help(wb)
# Out:
# Help on package wbgapi:
#
# NAME
#     wbgapi
#
# DESCRIPTION
#     wbgapi provides a comprehensive interface to the World Bank's data and
#     metadata API with built-in pandas integration
#
# PACKAGE CONTENTS
#     __version__
#     data
#     economy
#     economy_coder
#     economy_metadata
#     income
#     lending
#     region
#     series
#     series_metadata
#     source
#     time
#     topic
#     utils
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         APIError
#             APIResponseError
#         URLError
#     builtins.dict(builtins.object)
#         Coder
#     builtins.object
#         Featureset
#         Metadata
#         MetadataCollection
#
#     class APIError(builtins.Exception)
#      |  APIError(url, msg, code=None)
#      |
#      |  Method resolution order:
#      |      APIError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
# ...

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-09-16
# 3     Worldwide Governance Indicators                                       WGI              3  2022-09-23
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.economy.info()    #what countries do we have?
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...

# %%
wb.region.info()   #what regions do we have?
# Out:
# code    name
# ------  -----------------------------------------------------
# AFE     Africa Eastern and Southern
# AFR     Africa
# AFW     Africa Western and Central
# ARB     Arab World
# CAA     Sub-Saharan Africa (IFC classification)
# CEA     East Asia and the Pacific (IFC classification)
# CEB     Central Europe and the Baltics
# CEU     Europe and Central Asia (IFC classification)
# CLA     Latin America and the Caribbean (IFC classification)
# CME     Middle East and North Africa (IFC classification)
# CSA     South Asia (IFC classification)
# CSS     Caribbean small states
# EAP     East Asia & Pacific (excluding high income)
# EAR     Early-demographic dividend
# EAS     East Asia & Pacific
# ECA     Europe & Central Asia (excluding high income)
# ECS     Europe & Central Asia
# EMU     Euro area
# EUU     European Union
# FCS     Fragile and conflict affected situations
# HPC     Heavily indebted poor countries (HIPC)
# ...

# %%
wb.series.info()   #what series do we have?
# Out:
# id                         value
# -------------------------  --------------------------------------------------------------------------------------------------------------------------------------------
# AG.AGR.TRAC.NO             Agricultural machinery, tractors
# AG.CON.FERT.PT.ZS          Fertilizer consumption (% of fertilizer production)
# AG.CON.FERT.ZS             Fertilizer consumption (kilograms per hectare of arable land)
# AG.LND.AGRI.K2             Agricultural land (sq. km)
# AG.LND.AGRI.ZS             Agricultural land (% of land area)
# AG.LND.ARBL.HA             Arable land (hectares)
# AG.LND.ARBL.HA.PC          Arable land (hectares per person)
# AG.LND.ARBL.ZS             Arable land (% of land area)
# AG.LND.CREL.HA             Land under cereal production (hectares)
# AG.LND.CROP.ZS             Permanent cropland (% of land area)
# AG.LND.EL5M.RU.K2          Rural land area where elevation is below 5 meters (sq. km)
# ...

# %%
wb.series.info(q="gender")   #to display series related with gender
# Out:
# id                    value
# --------------------  ---------------------------------------------------------------------------
# IQ.CPA.GNDR.XQ        CPIA gender equality rating (1=low to 6=high)
# SE.ADT.1524.LT.FM.ZS  Literacy rate, youth (ages 15-24), gender parity index (GPI)
# SE.ENR.PRIM.FM.ZS     School enrollment, primary (gross), gender parity index (GPI)
# SE.ENR.PRSC.FM.ZS     School enrollment, primary and secondary (gross), gender parity index (GPI)
# SE.ENR.SECO.FM.ZS     School enrollment, secondary (gross), gender parity index (GPI)
# SE.ENR.TERT.FM.ZS     School enrollment, tertiary (gross), gender parity index (GPI)
#                       6 elements

# %%
wb.series.info(q="business")     #to display series related with business
# Out:
# id                    value
# --------------------  -------------------------------------------------------------------------------
# IC.BUS.DFRN.XQ        Ease of doing business score (0 = lowest performance to 100 = best performance)
# IC.BUS.DISC.XQ        Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# IC.BUS.EASE.XQ        Ease of doing business rank (1=most business-friendly regulations)
# IC.BUS.NDNS.ZS        New business density (new registrations per 1,000 people ages 15-64)
# IC.BUS.NREG           New businesses registered (number)
# IC.REG.COST.PC.FE.ZS  Cost of business start-up procedures, female (% of GNI per capita)
# IC.REG.COST.PC.MA.ZS  Cost of business start-up procedures, male (% of GNI per capita)
# IC.REG.COST.PC.ZS     Cost of business start-up procedures (% of GNI per capita)
# IC.REG.DURS           Time required to start a business (days)
# IC.REG.DURS.FE        Time required to start a business, female (days)
# ...

# %%
business = wb.data.DataFrame('IC.REG.DURS', wb.region.members('ECS'))
business
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# ALB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ARM         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AUT         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AZE         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BEL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGR         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BIH         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BLR         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHE         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHI         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CYP         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
#dataframe ('my data set', ... )

ren = wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST'], time=range(2003,2019))
ren
# Out:
#          YR2003  YR2004  YR2005  YR2006  YR2007  YR2008  YR2009  YR2010  \
# economy
# EST        72.0    72.0    35.0    35.0     6.5     6.5     6.5     6.5
# FRA        41.0     7.0     7.0     7.0     7.0     6.5     6.5     6.5
# UKR        41.0    35.0    35.0    34.0    28.0    28.0    28.0    28.0
#
#          YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018
# economy
# EST         6.5     6.5     6.5     4.5     3.5     3.5     3.5     3.5
# FRA         6.5     6.5     6.5     4.5     4.0     3.5     3.5     3.5
# UKR        25.0    23.0    22.0    22.0     8.0     6.5     6.5     6.5

# %%
ren.plot.bar()     #to visualize a basic plot
# Out:
# <AxesSubplot:xlabel='economy'>

# %%
wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST'], time=range(2000,2019,3)).T.plot()
# Out:
# <AxesSubplot:>

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[:3]    #the year that we want, ascending is in order from bigger to smalle = TRUE, the first 3 countries on business 
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
#LITTLE TASK

""""1. Interpret the data.
2.  Check the data about Start-up procedures to register a business 
3. Make a comparison for 5 countries on your choice"""

# IC.REG.PROC   -> Start-up procedures to register a business (number)
# Out:
# '"1. Interpret the data.\n2.  Check the data about Start-up procedures to register a business \n3. Make a comparison for 5 countries on your choice'

# %%
business = wb.data.DataFrame('IC.REG.PROC', wb.region.members('WLD'))
business
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AGO         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ALB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# XKX         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# YEM         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ZAF         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ZMB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ZWE         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# ...

# %%
ren = wb.data.DataFrame('IC.REG.PROC', ['FRA','ESP','ITA','GRC','USA'], time=range(2003,2019))
ren
# Out:
#          YR2003  YR2004  YR2005  YR2006  YR2007  YR2008  YR2009  YR2010  \
# economy
# ESP        10.0    10.0    10.0    10.0    10.0    10.0    10.0    10.0
# FRA         8.0     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# GRC        15.0    15.0    15.0    15.0    15.0    15.0    15.0    15.0
# ITA        10.0    10.0    10.0    10.0    10.0     7.0     8.0     8.0
# USA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018
# economy
# ESP        10.0    11.0    11.0     7.0     7.0     7.0     7.0     7.0
# FRA         5.0     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# GRC        11.0    11.0     5.0     5.0     5.0     5.0     4.0     4.0
# ITA         8.0     8.0     8.0     7.0     7.0     7.0     7.0     7.0
# USA         NaN     NaN     6.0     6.0     6.0     6.0     6.0     6.0

# %%
wb.data.DataFrame('IC.REG.PROC', ['FRA','ESP','ITA','GRC','USA'], time=range(2010,2020,3)).T.plot()
# Out:
# <AxesSubplot:>

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[:5]
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
# We're analysing how is the procedures to register a business as a start-up, this is, as bigger is the number on the
# axis 'y', as difficult is gonna be to open a new business because they're gonna have more steps to do it.
# We assume that the USA should have the easiest way to open a business (start-up) because they're gonna have 
# the less numbers of procedures to do it. We're assuming that because by history, USA is the country of the opportunities.
# With the statistics, we can say we have evidence to confirme this assumption, but USA is not the easiest country to do it.
# Surprisingly, we find Greece and France as the easiest countries to open a new businees as they have less steps
# to do it. Greece had a dropdown in 2013 related to the number of steps, maybe because they took a drastic
#changing their procedures in order to improve the economy of the country because of the crisis.
# As I can expect, because I know Spain as I'm Spanish, Spain is the most difficult country to open a new business
# because of the financial troubles to get money, also because of the high taxes we have to pay when we're opening
# a new business and we are not gaining money. And because of the similarities of the countries, we can think and 
# it's that way, Italy is the second country with more difficult procedures to open a business. Despite this, Spain
# and Italy converge in the recent years.

# %%
#wb.topic.info()
#wb.series.info(wb.topic.members(17))
