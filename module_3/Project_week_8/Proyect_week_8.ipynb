# %%
import pandas as pd
import numpy as np

# %%
apr = pd.read_csv(r'/Users/jaimesastrecrespo/DAFT_1022/module_3/Project_week_8/uber-raw-data-apr14.csv')

# %%
apr.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
apr.dtypes
# Out:
# Date/Time     object
# Lat          float64
# Lon          float64
# Base          object
# dtype: object

# %%
from datetime import datetime

# %%
apr['Date/Time'].iloc[0]
# Out:
# '4/1/2014 0:11:00'

# %%
# call datetime.strptime to convert
# it into datetime datatype
datetime_obj = datetime.strptime(apr['Date/Time'].iloc[0], 
                                 "%m/%d/%Y %H:%M:%S")

  
# extract the time from datetime_obj
hours = datetime_obj.time().hour
print(hours)
apr['Hour'] = apr['Date/Time'].apply(lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S").time().hour)
# Out:
# 0

# %%
apr.drop('Date/Time', axis=1, inplace=True)

# %%
del apr['Base']

# %%
apr.head()
# Out:
#        Lat      Lon  Hour
# 0  40.7690 -73.9549     0
# 1  40.7267 -74.0345     0
# 2  40.7316 -73.9873     0
# 3  40.7588 -73.9776     0
# 4  40.7594 -73.9722     0

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# %%
model = KMeans()
visualizer = KElbowVisualizer(estimator = model, k = (2,10))
visualizer.fit(apr[['Lat', 'Lon']])
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
model = KMeans(6 , random_state= 42)
model.fit(apr[['Lat', 'Lon']])
y_pred = model.predict(apr[['Lat', 'Lon']])

# %%
np.unique(y_pred, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5], dtype=int32),
#  array([216680,  59915, 249523,  14407,  19134,   4857]))

# %%
model.cluster_centers_
# Out:
# array([[ 40.76556828, -73.97281182],
#        [ 40.68856834, -73.96549626],
#        [ 40.73111913, -73.9985994 ],
#        [ 40.65951061, -73.77406315],
#        [ 40.79807196, -73.86873733],
#        [ 40.7005414 , -74.20167303]])

# %%
apr['Kcluster'] = model.labels_

# %%
apr.head()
# Out:
#        Lat      Lon  Hour  Kcluster
# 0  40.7690 -73.9549     0         0
# 1  40.7267 -74.0345     0         2
# 2  40.7316 -73.9873     0         2
# 3  40.7588 -73.9776     0         0
# 4  40.7594 -73.9722     0         0

# %%
# Let's sample

# %%
sample = apr.sample(frac = 0.02, random_state=42)

# %%
from sklearn import metrics

# %%
from sklearn.cluster import DBSCAN

# %%
for eps in np.round(np.arange(0.02, 0.03, 0.001),3):
    dbscan_cluster = DBSCAN(eps=eps)
    dbscan_cluster = dbscan_cluster.fit(sample[['Lat', 'Lon']])
    ypred = dbscan_cluster.fit_predict(sample[['Lat', 'Lon']])
    print("eps is:", eps)
    print("Score is:", metrics.silhouette_score(sample[['Lat', 'Lon']], ypred, metric="sqeuclidean"))
# Out:
# eps is: 0.02
# Score is: 0.8140154635161284
# eps is: 0.021
# Score is: 0.8137883613995639
# eps is: 0.022
# Score is: 0.871267598044826
# eps is: 0.023
# Score is: 0.8578741148017804
# eps is: 0.024
# Score is: 0.870654259300429
# eps is: 0.025
# Score is: 0.8706084826481892
# eps is: 0.026
# Score is: 0.8122149756957635
# eps is: 0.027
# Score is: 0.8122149756957635
# eps is: 0.028
# Score is: 0.8120675265773107
# eps is: 0.029
# Score is: 0.8122120657239045

# %%
dbscan_cluster1 = DBSCAN(eps = 0.022)
dbscan_cluster1= dbscan_cluster1.fit(sample[['Lat', 'Lon']])
y_pred = dbscan_cluster1.fit_predict(sample[['Lat', 'Lon']])

# %%
sample['DBScluster'] = y_pred

# %%
sample.head()
# Out:
#             Lat      Lon  Hour  Kcluster  DBScluster
# 77202   40.8021 -73.9654    10         0           0
# 558915  40.6462 -73.7769     4         3           1
# 152635  40.7747 -73.9603     9         0           0
# 361259  40.7150 -74.0157    23         2           0
# 60087   40.7335 -74.0080    19         2           0

# %%
np.unique(y_pred, return_counts=True)
# Out:
# (array([-1,  0,  1,  2,  3]), array([   95, 10877,   233,    78,     7]))

# %%
centroids = []
for label in np.unique(y_pred):
    centroids.append([sample.loc[sample['DBScluster'] == label]['Lat'].mean(),sample.loc[sample['DBScluster'] == label]['Lon'].mean()])

# %%
centroids
# Out:
# [[40.80038210526316, -73.8871452631579],
#  [40.74195362691927, -73.98028416842921],
#  [40.64595579399146, -73.78402746781113],
#  [40.692146153846174, -74.17964615384615],
#  [40.734657142857145, -74.1626]]

# %%
import folium
from folium.plugins import HeatMap

# %%
map = folium.Map(location=(sample['Lat'].mean(), sample['Lon'].mean()), zoom_start=10)

# Create the Heat Map
HeatMap(list(zip(sample['Lat'], sample['Lon']))).add_to(map)

for point in model.cluster_centers_:
    folium.Marker(location=(point[0], point[1]), icon=folium.Icon(icon="car", prefix='fa', color='gray')).add_to(map)

for point in centroids:
    folium.Marker(location=(point[0], point[1]), icon=folium.Icon(icon="car", prefix='fa', color='pink')).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33148ea0e25c6aef6c32b8165516495a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33148ea0e25c6aef6c32b8165516495a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_33148ea0e25c6aef6c32b8165516495a = L.map(
#                 &quot;map_33148ea0e25c6aef6c32b8165516495a&quot;,
#                 {
#                     center: [40.740115465013474, -73.97694054030161],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8e272505eec6470ff9ee060206858b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map
[40.7469, -73.9808], [40.7237, -73.9518], [40.7343, -74.0028], [40.7466, -73.9919], [40.7513, -73.9735], [40.7421, -73.9984], [40.7198, -73.9942], [40.7735, -73.9539], [40.752, -73.993], [40.7603, -73.9744], [40.7553, -73.9842], [40.6464, -73.7904], [40.7589, -73.9728], [40.7627, -73.9755], [40.7457, -73.9459], [40.7836, -73.9793], [40.7178, -73.9971], [40.7565, -73.9761], [40.7242, -73.8196], [40.7867, -73.9775], [40.7655, -73.9626], [40.7442, -73.9922], [40.7287, -74.0071], [40.7666, -73.9861], [40.7685, -73.987], [40.7394, -74.008], [40.7218, -74.0025], [40.7439, -74.0064], [40.7987, -73.9416], [40.761, -73.9733], [40.7333, -73.9889], [40.6868, -73.9457], [40.7318, -73.9969], [40.7579, -73.9733], [40.7535, -73.9889], [40.7653, -73.9618], [40.7627, -73.9653], [40.7361, -74.006], [40.7261, -73.9918], [40.7549, -73.994], [40.7272, -73.9789], [40.695, -74.1781], [40.7625, -73.9786], [40.7215, -73.9999], [40.749, -73.9738], [40.7518, -73.9726], [40.7327, -73.9982], [40.7516, -73.9902], [40.6898, -73.9929], [40.6943, -73.908], [40.7297, -73.9916], [40.7839, -73.9761], [40.7527, -73.9717], [40.7682, -73.9893], [40.7216, -74.0009], [40.7498, -74.0051], [40.7144, -74.0154], [40.7599, -73.9773], [40.7294, -74.001], [40.7383, -74.0039], [40.7019, -73.9897], [40.7109, -74.0078], [40.6997, -73.9806], [40.7708, -73.8657], [40.7529, -73.9678], [40.7451, -73.9757], [40.7591, -73.9825], [40.7542, -73.9943], [40.7622,

# %%
import seaborn as sns
sns.heatmap(pd.crosstab(apr.Hour, apr.Kcluster, normalize='columns'))
# Out:
# <AxesSubplot:xlabel='Kcluster', ylabel='Hour'>

# %%
sns.heatmap(pd.crosstab(sample.Hour, sample['DBScluster'], normalize='columns'))
# Out:
# <AxesSubplot:xlabel='DBScluster', ylabel='Hour'>

# %%
sep = pd.read_csv(r'/Users/jaimesastrecrespo/DAFT_1022/module_3/Project_week_8/uber-raw-data-sep14.csv')

# %%
samples = sep.sample(frac = 0.02, random_state=42)

# %%
map = folium.Map(location=(samples['Lat'].mean(), samples['Lon'].mean()), zoom_start=10)

# Create the Heat Map
HeatMap(list(zip(samples['Lat'], samples['Lon']))).add_to(map)

for point in model.cluster_centers_:
    folium.Marker(location=(point[0], point[1]), icon=folium.Icon(icon="car", prefix='fa', color='gray')).add_to(map)

for point in centroids:
    folium.Marker(location=(point[0], point[1]), icon=folium.Icon(icon="car", prefix='fa', color='pink')).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16ba63d06cc3a811ecf9250072dcf70e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16ba63d06cc3a811ecf9250072dcf70e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_16ba63d06cc3a811ecf9250072dcf70e = L.map(
#                 &quot;map_16ba63d06cc3a811ecf9250072dcf70e&quot;,
#                 {
#                     center: [40.73882796284566, -73.97190435734085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer
40.7295, -73.9897], [40.5962, -73.9903], [40.7634, -73.9868], [40.7594, -73.9945], [40.7333, -73.9898], [40.7501, -73.978], [40.7505, -73.9946], [40.7248, -73.9989], [40.807, -73.9476], [40.7271, -73.9803], [40.7631, -73.9743], [40.7347, -73.9922], [40.7419, -73.9825], [40.7139, -73.9545], [40.8445, -73.9364], [40.7741, -73.8724], [40.763, -73.972], [40.7595, -73.9911], [40.6827, -73.9932], [40.6815, -74.0008], [40.9568, -73.8528], [40.691, -73.9968], [40.7237, -74.0036], [40.7237, -73.9994], [40.6013, -73.9714], [40.7507, -73.9801], [40.6753, -73.989], [40.7445, -73.932], [40.6865, -73.9227], [40.7449, -73.9912], [40.728, -73.9825], [40.7584, -73.9824], [40.7308, -73.9834], [40.6545, -73.9462], [40.7226, -73.9979], [40.7286, -74.0054], [40.708, -74.0095], [40.7328, -73.9911], [40.7437, -73.9857], [40.6781, -73.962], [40.6871, -73.9757], [40.7756, -73.9535], [40.7394, -73.9871], [40.7191, -73.9641], [40.7967, -73.9712], [40.6457, -73.7766], [40.7254, -74.0035], [40.6905, -74.1777], [40.7507, -73.9783], [40.7249, -73.9873], [40.7257, -74.0058], [40.6447, -73.7819], [40.7325, -73.9984], [40.7277, -73.8605], [40.6813, -73.9846], [40.7586, -73.9687], [40.77, -73.9492], [40.7673, -73.8864], [40.6987, -73.9382], [40.7272, -74.0], [40.7505, -73.9792], [40.738, -73.9882], [40.7679, -73.9915], [40.8517, -73.9417], [40.7578, -73.9733], [40.7516, -74.005], [40.7551, -73.995], [40.7462, -74.0052], [40.7539, -73.9783], [40.7587, -73.9719], [40.7221, -74.0097], [40.7501, -73.9845], [40.7306, -73.9926], [40.7444, -73.9917], [40.7423, -73.9892], [40.7382, -74.006], [40.7498, -73.9922], [40.6853, -73.958], [40.7152, -73.9449], [4

# %%
from sklearn.metrics import silhouette_score
from sklearn import metrics

# %%
print("Silhouette Coefficient for KMeans: %0.3f \n"
    % metrics.silhouette_score(sample[['Lat', 'Lon']], sample['Kcluster'], metric="sqeuclidean"))
print("Silhouette Coefficient for DBSCAN: %0.3f \n"
    % metrics.silhouette_score(sample[['Lat', 'Lon']], sample['DBScluster'], metric="sqeuclidean"))
# Out:
# Silhouette Coefficient for KMeans: 0.628
#
# Silhouette Coefficient for DBSCAN: 0.871

# %%
print("Silhouette Coefficient for KMeans: %0.3f \n"
    % metrics.silhouette_score(samples[['Lat', 'Lon']], model.predict(samples[['Lat', 'Lon']]), metric="sqeuclidean"))
print("Silhouette Coefficient for DBSCAN: %0.3f \n"
    % metrics.silhouette_score(samples[['Lat', 'Lon']], dbscan_cluster1.fit_predict(samples[['Lat', 'Lon']]), metric="sqeuclidean"))
# Out:
# Silhouette Coefficient for KMeans: 0.551
#
# Silhouette Coefficient for DBSCAN: 0.769
