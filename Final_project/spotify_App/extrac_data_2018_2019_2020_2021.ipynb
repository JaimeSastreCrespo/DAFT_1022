# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 



# Importing necessary libraries and settings
import time
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import random
from functools import reduce
import spotipy.util as util
from spotipy import oauth2
from pathlib import Path

# %%
path = Path("/Users/jaimesastrecrespo/DAFT_1022/Final_project/spotify_App")

# %%
with open(path / "client_s.txt") as f:
    content = f.readlines()
content = [x.strip() for x in content]

# %%
client_id = content[0]
client_secret = content[1]
redirect_uri = 'http://localhost:7777/callingmoi'
username = content[3]

# %%
scope = "user-library-read user-read-recently-played user-top-read playlist-modify-public playlist-read-private playlist-read-collaborative"

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

# %%
#my top 100 in 2019
ids = getTrackIDs(user = '119242281', playlist_id = '37i9dQZF1EtdfiLotZtf3K')

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df2019 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
#df2019.to_csv("my_spotify_2019.csv", sep = ',')

# %%
df2019.shape
# Out:
# (100, 16)

# %%
#my top 100 in 2018
ids2018 = getTrackIDs(user = '119242281', playlist_id = '37i9dQZF1EjlGNlHTUaWxC')

# %%
# loop over track ids2018 
tracks2018 = []
for i in range(len(ids2018)):
  time.sleep(.5)
  track = getTrackFeatures(ids2018[i])
  tracks2018.append(track)

# create dataset
df2018 = pd.DataFrame(tracks2018, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
#df2018.to_csv("my_spotify_2018.csv", sep = ',')

# %%
df2018.head()
# Out:
#                  name               album           artist release_date  \
# 0     Fresas con nata     Fresas con nata      Ayax y Prok   2018-02-21
# 1                Amén          Pa'l Coche  Various Artists   2017-02-09
# 2  Llórame - Acústico  Llórame (Acústico)          Zetazen   2018-03-16
# 3        Nit salvatge        Nit salvatge    Smoking Souls   2015-12-14
# 4            Amorfoda            Amorfoda        Bad Bunny   2018-02-15
#
#    length  popularity  danceability  acousticness  danceability  energy  \
# 0  210000           0         0.824      0.126000         0.824   0.617
# 1  191478          42         0.685      0.130000         0.685   0.480
# 2  233453          45         0.537      0.946000         0.537   0.468
# 3  259833          40         0.587      0.000089         0.587   0.675
# 4  155675           0         0.742      0.984000         0.742   0.432
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# ...

# %%
#my top 100 in 2020
ids2020 = getTrackIDs(user = '119242281', playlist_id = '37i9dQZF1ELXwPxY6XKPiF')

# %%
type(ids2020)
# Out:
# list

# %%
# loop over track ids2020 
tracks2020 = []
for i in range(len(ids2020)):
  time.sleep(.5)
  track = getTrackFeatures(ids2020[i])
  tracks2020.append(track)

# create dataset
df2020 = pd.DataFrame(tracks2020, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
#df2020.to_csv("my_spotify_2020.csv", sep = ',')

# %%
df2020.head()
# Out:
#                                           name  \
# 0                    A las Cosas por Su Nombre
# 1                                    Good News
# 2  Dani Ribba: Bzrp Freestyle Sessions, Vol. 7
# 3                                En tu agujero
# 4                             Como el Sol 2011
#
#                                          album                artist  \
# 0                          Vivir para Contarlo  Violadores Del Verso
# 1                                    Good News            Mac Miller
# 2  Dani Ribba: Bzrp Freestyle Sessions, Vol. 7              Bizarrap
# 3                               Besos de Perro                 Marea
# 4                        Kase.O Jazz Magnetism                Kase.O
#
#   release_date  length  popularity  danceability  acousticness  danceability  \
# 0         2006  259920          46         0.885        0.2140         0.885
# 1   2020-01-09  342040          55         0.794        0.8530         0.794
# ...

# %%
playlist_link = "https://open.spotify.com/user/spotify/playlist/37i9dQZF1ELXwPxY6XKPiF?si=QadDeolyS2u2d9ffyCKzxw"

playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris2021 = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
# loop over track ids2021
tracks2021 = []
for i in range(len(track_uris2021)):
  time.sleep(.5)
  track = getTrackFeatures(track_uris2021[i])
  tracks2021.append(track)

# create dataset
df2021 = pd.DataFrame(tracks2021, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
#df2021.to_csv("my_spotify_2021.csv", sep = ',')

# %%
df2021.tail()
# Out:
#                                                  name  \
# 95                                              Naive
# 96                                               Time
# 97                                       Quick Escape
# 98                                   Tear in My Heart
# 99  Medley:Javat y Kamel/Amberes/Reunion/Kieres - ...
#
#                            album                artist release_date  length  \
# 95        Inside In / Inside Out             The Kooks   2006-01-01  203506
# 96                          Time        Free Nationals   2019-06-12  210279
# 97                  Quick Escape             Pearl Jam   2020-03-25  286573
# 98                    Blurryface     Twenty One Pilots   2015-05-15  188493
# 99  Gira 06/07 - Presente (Live)  Violadores Del Verso   2007-12-07  763306
#
#     popularity  danceability  acousticness  danceability  energy  \
# 95          74         0.391      0.075900         0.391   0.808
# ...
