# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x, y, label='linear')
plt.plot(x, z, label='quadratic')
plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Linear and quadratic plots")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)
ax1.set_title('LIN PLOT')
ax1.plot(x,y,label='lin' )
ax1.set_xlabel('x lab')     
ax1.set_ylabel('y lab')

ax2.set_title('QUAD PLOT')
ax2.plot(x,z, label='quad' )
ax2.set_xlabel('x lab')     
ax2.set_ylabel('z lab')
fig.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax1.set_title('LIN PLOT', fontweight='bold')
ax1.plot(x,y,label='lin' )
ax1.set_xlabel('x lab')     
ax1.set_ylabel('y lab')

ax2.set_title('QUAD PLOT', fontweight='bold')
ax2.plot(x,z, label='quad' )
ax2.set_xlabel('x lab')     
ax2.set_ylabel('z lab')
fig.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax1.set_title('Normal scale', fontweight='bold')
ax1.plot(x**2, label='label norm')
ax1.set_xlabel('x lab')     
ax1.set_ylabel('y lab')

ax2.set_title('Log scale', fontweight='bold')
ax2.plot(x**2, label='label log')
ax2.set_xlabel('x lab')     
ax2.set_ylabel('z lab')
ax2.set_yscale('log')

fig.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r'./Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %%
# MEDIAN STEPS BY MONTH_ENCODED

median_per_month = fitbit[['Steps','Months_encoded']].groupby('Months_encoded').agg('median')
median_per_month.plot.bar().get_figure().savefig(r'/Users/jaimesastrecrespo/DAFT_1022/module_2/Lab_1_Matplotlib-and-Seaborn/figures/median_steps_per_month')



# MEDIAN STEPS BY WORK_OR_WEEKEND

median_per_month = fitbit[['Steps','Work_or_Weekend']].groupby('Work_or_Weekend').agg('median')
median_per_month.plot.bar().get_figure().savefig(r'./figures/median_steps_work_or_we')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary' ]
for i in features:
    plt.figure()
    sns.scatterplot(x=i, y="Steps", data=fitbit)

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv(r'./titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.dtypes[(titanic.dtypes == 'float64') | (titanic.dtypes == 'int64')]
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
# CATEGORICAL VARIABLES
titanic.dtypes[titanic.dtypes == 'object']
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.rcParams["figure.figsize"] = (12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
histograma = titanic.hist(column='Age', bins=20)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

titanic.hist(column='Age', bins=50, ax=axes[0])
titanic.hist(column='Age', bins=20, ax=axes[1])
titanic.hist(column='Age', bins=10, ax=axes[2])
# Out:
# array([<AxesSubplot:title={'center':'Age'}>], dtype=object)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
 the plot looks like a normal distribution and you can see better the peaks
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.displot(titanic, x="Age")

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic['Gender'].value_counts().plot.bar()

#need use value_counts to transform the data into something countable
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn
sns.countplot(x=titanic["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(data=titanic, x="Pclass")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x="Age",data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
Boxplot because it gives you all the main stats.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Centered close to 30
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
## ?

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
lines = titanic.plot.scatter(x='Age', y='Fare')

# %%
# Method 2 - seaborn
sns.regplot("Age", "Fare", data=titanic)
# Out:
# /Users/jaimesastrecrespo/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr());

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Survived with Fare and SibSp with Parch.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x="Pclass", y="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="Gender")
g.map_dataframe(sns.histplot, x="Age", binwidth=4, binrange=(0, 70))
